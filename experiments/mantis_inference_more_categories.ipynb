# %%
import os
import sys
WORKING_DIR = os.path.dirname(os.path.abspath('./'))
print(WORKING_DIR)
sys.path.append(WORKING_DIR)
# Out:
# /Users/lorenz/Repos/extractify/backend

# %%
# randomly select 150 categories
import random

random.seed(0)
given_categories = [
    "stats",
    "dba",
    "askubuntu",
    "gaming",
    "travel",
    "apple",
    "electronics",
    "english",
    "security",
    "physics",
    "gis",
    "scifi",
    "worldbuilding",
    "diy",
]
# selected_topics_150_random = random.sample(list(df_topics["TagName"]), 150)

# # combine the given categories with the randomly selected categories and randomly shuffle them
# selected_topics_150_random = given_categories + selected_topics_150_random
# random.shuffle(selected_topics_150_random)
# print(selected_topics_150_random)
# print(len(selected_topics_150_random))

selected_topics_150_random = [
                    "elementor",
                    "gantt-chart",
                    "conditional-operator",
                    "google-glass",
                    "visual-c++-6",
                    "uisearchbar",
                    "table-valued-parameters",
                    "directoryservices",
                    "physics",
                    "fuseki",
                    "openapi",
                    "branch",
                    "qt-quick",
                    "asymptotic-complexity",
                    "mouseenter",
                    "scifi",
                    "ckeditor4.x",
                    "eventkit",
                    "scapy",
                    "destructor",
                    "mercurial",
                    "google-play",
                    "mingw",
                    "gcc-warning",
                    "vhosts",
                    "uiactionsheet",
                    "yelp",
                    "glib",
                    "retry-logic",
                    "calabash",
                    "config",
                    "stdin",
                    "azure-powershell",
                    "english",
                    "right-to-left",
                    "electronics",
                    "rasterio",
                    "drawrect",
                    "icmp",
                    "diy",
                    "absolute",
                    "telegram-bot",
                    "nginx-location",
                    "big-o",
                    "speech-synthesis",
                    "facebook-prophet",
                    "sparql",
                    "apache-phoenix",
                    "robots.txt",
                    "worldbuilding",
                    "teradata-sql-assistant",
                    "video",
                    "gif",
                    "mdf",
                    "digital-ocean",
                    "quaternions",
                    "askubuntu",
                    "xcode5",
                    "bridge",
                    "corda",
                    "datastax-java-driver",
                    "backgroundworker",
                    "odp.net",
                    "itext7",
                    "image-scaling",
                    "opc-ua",
                    "leveldb",
                    "security",
                    "google-maps-markers",
                    "swift-protocols",
                    "operating-system",
                    "codeblocks",
                    "admin-on-rest",
                    "travel",
                    "channel",
                    "ractivejs",
                    "git-config",
                    "numpy-slicing",
                    "self-join",
                    "data-visualization",
                    "openshift-origin",
                    "openai-gym",
                    "androiddesignsupport",
                    "reindex",
                    "stats",
                    "nhibernate-mapping",
                    "css-tables",
                    "internet-explorer",
                    "livecode",
                    "alamofire",
                    "nosql",
                    "brightness",
                    "android-snackbar",
                    "sqlcmd",
                    "f#",
                    "codemirror",
                    "typescript-typings",
                    "google-docs",
                    "redux-toolkit",
                    "overriding",
                    "pull-request",
                    "nvd3.js",
                    "joomla",
                    "mailto",
                    "preg-match",
                    "xamarin.mac",
                    "openiddict",
                    "addressbook",
                    "discord",
                    "openapi-generator",
                    "subscribe",
                    "dba",
                    "union",
                    "postcss",
                    "std-ranges",
                    "ado.net-entity-data-model",
                    "opl",
                    "ruby-1.9.3",
                    "unauthorized",
                    "azure-devops-rest-api",
                    "httpcookie",
                    "gridsearchcv",
                    "iterable",
                    "fixtures",
                    "web-component",
                    "android-sharedpreferences",
                    "avaudiorecorder",
                    "windbg",
                    "micronaut",
                    "gaming",
                    "angularjs-ng-click",
                    "fill",
                    "spinner",
                    "laravel-artisan",
                    "qlabel",
                    "csrf",
                    "mobilefirst-server",
                    "bittorrent",
                    "etcd",
                    "words",
                    "android-jetpack-navigation",
                    "doctype",
                    "bitmapdata",
                    "case",
                    "pause",
                    "arm64",
                    "gis",
                    "calloc",
                    "rollback",
                    "contact-form-7",
                    "filechooser",
                    "systemctl",
                    "javascriptserializer",
                    "android-navigation",
                    "autorotate",
                    "asp.net",
                    "x++",
                    "sql-delete",
                    "volume",
                    "redis",
                    "grepl",
                    "x86-16",
                    "apple",
                    "cgrect",
                ],

# %%
from foundation_models.chat_openai import AIModelType
import pandas as pd
df = pd.read_csv("../dataset/mantis_json_dataset_with_intents/mantis_utterance_category.csv")
current_model = AIModelType.GPT3

# %%
import json

from entity_linking import EntityLinking
from foundation_models.chat_openai import AIModelType
from schema import topic_schema_more_categories



async def link_entities(message: str):
    # generate function call schema
    schema = topic_schema_more_categories
    
    # gemerate function calling schema
    llm_module = EntityLinking(schema=schema,model=current_model)
    
    print("current_model:", current_model)
    
    if current_model == AIModelType.MISTRAL_LARGE or current_model == AIModelType.MISTRAL_MIXTRAL_8x22B or current_model == AIModelType.MISTRAL_SMALL:
        filter_generator_output = llm_module.generate_sync(conversation=message)
        return filter_generator_output
    if current_model == AIModelType.GPT4_O or current_model == AIModelType.GPT4_TURBO or current_model == AIModelType.GPT4_O_MINI or current_model == AIModelType.GPT3 or current_model == AIModelType.GOOGLE_GEMINI_PRO or current_model == AIModelType.CLAUDE_OPUS or current_model == AIModelType.CLAUDE_SONNET:
        filter_generator_output = await llm_module.generate_response_generic(conversation=message)
    else:
        filter_generator_output = await llm_module.generate_async(conversation=message)
        
    print("filter_generator_output:", filter_generator_output)
    
    return filter_generator_output
        
    
# test the function
message = "I am currently trying to mask the OS system I am using from the websites I visit. I'm doing this for an added layer of security. How would I go about hiding the OS from websites?"
response = await link_entities(message)
print("response:", response)

# save to json file
with open('./temp.json', 'w') as f:
    json.dump(response, f, indent=4, ensure_ascii=False)
# Out:
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# I am currently trying to mask the OS system I am using from the websites I visit. I'm doing this for an added layer of security. How would I go about hiding the OS from websites?
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8ZZhTSpPdBdGCWaQdCZlNquZkZo', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='[]', refusal=None, role='assistant', function_call=None, tool_calls=None))], created=1732461141, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=2, prompt_tokens=1169, total_tokens=1171, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 33
#      31 # test the function
#      32 message = "I am currently trying to mask the OS system I am using from the websites I visit. I'm doing this for an added layer of security. How would I go about hiding the OS from websites?"
# ---> 33 response = await link_entities(message)
#      34 print("response:", response)
#      36 # save to json file
#
# Cell In[4], line 22, in link_entities(message)
#      20     return filter_generator_output
#      21 if current_model == AIModelType.GPT4_O or current_model == AIModelType.GPT4_TURBO or current_model == AIModelType.GPT4_O_MINI or current_model == AIModelType.GPT3 or current_model == AIModelType.GOOGLE_GEMINI_PRO or current_model == AIModelType.CLAUDE_OPUS or current_model == AIModelType.CLAUDE_SONNET:
# ---> 22     filter_generator_output = await llm_module.generate_response_generic(conversation=message)
#      23 else:
#      24     filter_generator_output = await llm_module.generate_async(conversation=message)
#
# File ~/Repos/extractify/backend/foundation_models/openai_function_calling.py:134, in ChatOpenAIFunctionCalling.generate_response_generic(self, prompt)
#     131 print("self.functions", self.functions)
#     132 print("response", response)
# --> 134 return json.loads(response.choices[0].message.function_call.arguments)
#
# AttributeError: 'NoneType' object has no attribute 'arguments'

# %%
import pandas as pd
# import json
df = pd.read_json(f"prediction_mantis_more_categories_{current_model}_v1.json")

# %%
# iterate over rows with iterrows()
import asyncio
import json

tasks = []

for index, row in df.iterrows():
    predicted_entities = row[2]

    if predicted_entities is not None and type(predicted_entities) == str:
        print("Already predicted entities")
        continue

    print(row)
    query = row[0]
    actual_category = row[1]
    print(actual_category)
    print(query)

    async def recognize_and_return_index(
        index, message: str
    ):
        recognized_filters = (
            await link_entities(
                message=message,
            )
        )
        
        
        predicted_category = recognized_filters.get("category")
        
        if predicted_category is None:
            predicted_category = "None"
        
        print("insert at",index)

        df.at[index, "Prediction"] = predicted_category
        return index

    print(index)
    
    # try:
    await recognize_and_return_index(
        index=index,
        message=query,
    )
        
    # except Exception as e:
    #     print(e)
    #     continue

    # wait to avoid rate limiting
    # await asyncio.sleep(5)

 
    # write to csv
    df.to_json(f"prediction_mantis_more_categories_{current_model}_v1.json", index=False, orient="records")


print(len(tasks))
# Out:
# /var/folders/lj/dk78kkr16dxcgq62lqvfy19c0000gn/T/ipykernel_88331/1281337151.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   predicted_entities = row[2]
# /var/folders/lj/dk78kkr16dxcgq62lqvfy19c0000gn/T/ipykernel_88331/1281337151.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   query = row[0]
# /var/folders/lj/dk78kkr16dxcgq62lqvfy19c0000gn/T/ipykernel_88331/1281337151.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   actual_category = row[1]
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# Already predicted entities
# category                                                  stats
# utterance     In the boosting algorithm,AdaBoost ,those obse...
# Prediction                                                 None
# Name: 39, dtype: object
# In the boosting algorithm,AdaBoost ,those observations which were misclassified by the classifier in the (m-1)th step have their weights increased in the mth step, and those which were correctly classified have their weights decreased. My question is, that isn't it possible that the new classifier now classifies the low weights ones wrong ,so that this cycle can continue and not yield much of a benefit?
# stats
# 39
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# stats
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8ghZ6ccJNYFZU97vBZzntLQIm5H', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "stats" }', name='entity_linking'), tool_calls=None))], created=1732461583, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=18, prompt_tokens=1131, total_tokens=1149, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'stats'}
# insert at 39
# category                                                physics
# utterance     While frying some chicken I was wondering why ...
# Prediction                                                 None
# Name: 40, dtype: object
# While frying some chicken I was wondering why the fat becomes transparent when melting.As far as I know, transparency is caused by the fact that the substance can't absorb photons of visible light (due to band gap or other excitation mechanisms)Is this the reason for liquid/solid fat as well? How does the fat lose excitation possibilities when molten?
# physics
# 40
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# physics
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8ghmEdJ0rUrugG4sEBzMFWKBpAO', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "physics" }', name='entity_linking'), tool_calls=None))], created=1732461583, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=18, prompt_tokens=1131, total_tokens=1149, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'physics'}
# insert at 40
# category                                                  scifi
# utterance     When I was a child, this would have been aroun...
# Prediction                                                 None
# Name: 41, dtype: object
# When I was a child, this would have been around 1990's and later, I watched an animated movie where there were a group of Pegasus living by a waterfall and mountainous area. There were both white and black Pegasus. If I am remembering it right they spoke (although I could be mistaken). Perhaps it wasn't a movie but a series of some kind?It isn't Fantasia as I have re-watched it and came back with a vehement no.It isn't The Last Unicorn.
# scifi
# 41
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# scifi
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8giap3QTEditpRRjx9WZf9Jq8eC', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "scifi" }', name='entity_linking'), tool_calls=None))], created=1732461584, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=19, prompt_tokens=1132, total_tokens=1151, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'scifi'}
# insert at 41
# category                                            electronics
# utterance     <a href="https://i.stack.imgur.com/bOgab.jpg" ...
# Prediction                                                 None
# Name: 42, dtype: object
# <a href="https://i.stack.imgur.com/bOgab.jpg" rel="nofollow noreferrer">In the previous FM receiver, how does the left transistor amplify the input radio signal from the antenna at the collector and output it at the base, from what i know the base always has a smaller current than the collector.
# electronics
# 42
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# electronics
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8gjbqbHGVmzXS6O7695MBsbExvG', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "electronics" }', name='entity_linking'), tool_calls=None))], created=1732461585, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=18, prompt_tokens=1131, total_tokens=1149, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'electronics'}
# insert at 42
# category                                                  scifi
# utterance     Early in Jumanji (1995) we learn Judy and Pete...
# Prediction                                                 None
# Name: 43, dtype: object
# Early in Jumanji (1995) we learn Judy and Peter’s parents died in an accident while they were young. Instead, the children are raised by a woman named Nora.I don’t ever remember the film explaining who Nora was, or why she presumably adopted Judy and Peter.Is Nora’s relation with Judy and Peter ever explained?
# scifi
# 43
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# scifi
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8gkhJ30qfZE5EqXxdWihYX9QbD7', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "scifi" }', name='entity_linking'), tool_calls=None))], created=1732461586, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=19, prompt_tokens=1132, total_tokens=1151, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'scifi'}
# insert at 43
# category                                              askubuntu
# utterance     What do I need to do to connect a Sony PS2 eye...
# Prediction                                                 None
# Name: 44, dtype: object
# What do I need to do to connect a Sony PS2 eyetoy camera to a Dell laptop (Ubuntu 14.04) or a Pandaboard (Ubuntu 12.04)?
# askubuntu
# 44
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# askubuntu
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8glOuoQ2lFpA6alw4I4E26rmYK5', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{"category":"askubuntu"}', name='entity_linking'), tool_calls=None))], created=1732461587, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=16, prompt_tokens=1132, total_tokens=1148, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'askubuntu'}
# insert at 44
# category                                          worldbuilding
# utterance     I read somewhere that the lowest depth for a s...
# Prediction                                                 None
# Name: 45, dtype: object
# I read somewhere that the lowest depth for a sustainable underwater habitat is estimated to be three-hundred meters. Any lower and the pressure becomes too great for structures that are currently within our means to build.How would such depths affect a pressurized underwater structure on a planet with lower gravity? Would it be unreasonable to say it could be done and would withstand the sea's erosion over a century or two?
# worldbuilding
# 45
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# worldbuilding
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8gluaM0NUOZRWljLrZz36lrXuUD', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "worldbuilding" }', name='entity_linking'), tool_calls=None))], created=1732461587, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=19, prompt_tokens=1132, total_tokens=1151, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'worldbuilding'}
# insert at 45
# category                                                  stats
# utterance     1) Is there an intuitive explanation for why d...
# Prediction                                                 None
# Name: 46, dtype: object
# 1) Is there an intuitive explanation for why data becomes correlated once rotated into the principal component basis?2) Is there any intuitive explanation behind why rotation doesn't affect the whitening of data?Specifically, I want to understand why $x_{ZCA} = U x_{PCA}$ where $x_{PCA} = D^{-1/2} U$ for the eigen decomposition of $X X^T$ works.
# stats
# 46
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# stats
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8gmtToJR8Ej9QXnMrLn4AuZ78X7', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "stats" }', name='entity_linking'), tool_calls=None))], created=1732461588, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=18, prompt_tokens=1131, total_tokens=1149, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'stats'}
# insert at 46
# category                                              askubuntu
# utterance     I'm setting up a desktop for the first time an...
# Prediction                                                 None
# Name: 47, dtype: object
# I'm setting up a desktop for the first time and having issues with making sure all the drivers for sound and graphics work.  I looked for any troubleshooters and there are none to be found.  I am new to Ubuntu and using 16.04
# askubuntu
# 47
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# askubuntu
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8go89stnJuITsDbEcZiQMRjOsAT', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "askubuntu" }', name='entity_linking'), tool_calls=None))], created=1732461590, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=19, prompt_tokens=1132, total_tokens=1151, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'askubuntu'}
# insert at 47
# category                                                physics
# utterance     Like my topic, I'd like to know why we need to...
# Prediction                                                 None
# Name: 48, dtype: object
# Like my topic, I'd like to know why we need to analyze the forward-backward asymmetry:$$A_{FB}=\frac{\int_0^1dz\frac{d\sigma}{dz}-\int_{-1}^0dz\frac{d\sigma}{dz}}{\int_{-1}^1dz\frac{d\sigma}{dz}}$$in particle physics. What physical concept does it relates to?
# physics
# 48
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# physics
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8gsuGO3Mt5dynpYDS8ew3VwkcYy', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "physics" }', name='entity_linking'), tool_calls=None))], created=1732461594, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=18, prompt_tokens=1131, total_tokens=1149, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# ...
# response ChatCompletion(id='chatcmpl-AX8hctto0aLktAaGJ2wFr8sIvuhvX', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "electronics" }', name='entity_linking'), tool_calls=None))], created=1732461640, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=18, prompt_tokens=1131, total_tokens=1149, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'electronics'}
# insert at 106
# category                                                    gis
# utterance     It is commonly a problem when you need all poi...
# Prediction                                                 None
# Name: 107, dtype: object
# It is commonly a problem when you need all points to be labelled, but due to high density of points it is difficult to understand the ties between points and labels. Arrows would be a way, but I haven't found anything similar even in SLD extensions.
# gis
# 107
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# gis
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8hd77zYQjfw13c43aWCnGM1CYr2', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "gis" }', name='entity_linking'), tool_calls=None))], created=1732461641, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=18, prompt_tokens=1131, total_tokens=1149, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'gis'}
# insert at 107
# category                                                    gis
# utterance     I use a little algorithm to transform values f...
# Prediction                                                 None
# Name: 108, dtype: object
# I use a little algorithm to transform values from an openstreetmap-file into a table (.dbf).I use the function: GetFieldAsString("string") from ogr.py and everything is fine, but when the "string" contains a char like "_" or ":" the error:<pre><code>ERROR1: Invalid field name: 'string_string'</code></pre>appear.(The function I use comes from <a href="https://pcjericks.github.io/py-gdalogr-cookbook/vector_layers.html#create-a-new-shapefile-and-add-data" rel="nofollow noreferrer">there)
# gis
# 108
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# gis
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8heb4sWxyTB7ULUY7wo50tLaNqn', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "gis" }', name='entity_linking'), tool_calls=None))], created=1732461642, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=18, prompt_tokens=1131, total_tokens=1149, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'gis'}
# insert at 108
# category                                                 gaming
# utterance     When I create a server by SteamCMD, should I s...
# Prediction                                                 None
# Name: 109, dtype: object
# When I create a server by SteamCMD, should I see my addons I subscribed? just like when I play an offline server? or my addons aren't active in the dedicated server?
# gaming
# 109
# current_model: AIModelType.GPT3
# prompt
# Gegeben ist folgende Anfrage:s
#
# Query:
# gaming
#
# Extrahiere die gewünschten Filterwerte aus der Konversation, nutze dabei nur die zur Verfügung stehenden Filterwerte. Bedenke aber auch implizite Filterwerte, die nicht explizit genannt werden,
# aber aus dem Kontext hervorgehen und helfen dem Kunden das passende Produkt zu finden.
#
# Denke dabei Schritt für Schritt vor und nutze die Funktionen, die dir zur Verfügung stehen. Erfinde keine neuen Werte in den Filter Werten.
# Wenn du für das Gespräch keine passendes Filter Werte findest, gib ein leeres Array zurück. Benutze aber immer die Funktionen, die dir zur Verfügung stehen.
#
# self.functions [{'name': 'entity_linking', 'description': 'Extract fitting values for the filter from the query', 'parameters': {'title': 'Intent Category Linking', 'type': 'object', 'properties': {'category': {'type': 'string', 'enum': ['elementor', 'gantt-chart', 'conditional-operator', 'google-glass', 'visual-c++-6', 'uisearchbar', 'table-valued-parameters', 'directoryservices', 'physics', 'fuseki', 'openapi', 'branch', 'qt-quick', 'asymptotic-complexity', 'mouseenter', 'scifi', 'ckeditor4.x', 'eventkit', 'scapy', 'destructor', 'mercurial', 'google-play', 'mingw', 'gcc-warning', 'vhosts', 'uiactionsheet', 'yelp', 'glib', 'retry-logic', 'calabash', 'config', 'stdin', 'azure-powershell', 'english', 'right-to-left', 'electronics', 'rasterio', 'drawrect', 'icmp', 'diy', 'absolute', 'telegram-bot', 'nginx-location', 'big-o', 'speech-synthesis', 'facebook-prophet', 'sparql', 'apache-phoenix', 'robots.txt', 'worldbuilding', 'teradata-sql-assistant', 'video', 'gif', 'mdf', 'digital-ocean', 'quaternions', 'askubuntu', 'xcode5', 'bridge', 'corda', 'datastax-java-driver', 'backgroundworker', 'odp.net', 'itext7', 'image-scaling', 'opc-ua', 'leveldb', 'security', 'google-maps-markers', 'swift-protocols', 'operating-system', 'codeblocks', 'admin-on-rest', 'travel', 'channel', 'ractivejs', 'git-config', 'numpy-slicing', 'self-join', 'data-visualization', 'openshift-origin', 'openai-gym', 'androiddesignsupport', 'reindex', 'stats', 'nhibernate-mapping', 'css-tables', 'internet-explorer', 'livecode', 'alamofire', 'nosql', 'brightness', 'android-snackbar', 'sqlcmd', 'f#', 'codemirror', 'typescript-typings', 'google-docs', 'redux-toolkit', 'overriding', 'pull-request', 'nvd3.js', 'joomla', 'mailto', 'preg-match', 'xamarin.mac', 'openiddict', 'addressbook', 'discord', 'openapi-generator', 'subscribe', 'dba', 'union', 'postcss', 'std-ranges', 'ado.net-entity-data-model', 'opl', 'ruby-1.9.3', 'unauthorized', 'azure-devops-rest-api', 'httpcookie', 'gridsearchcv', 'iterable', 'fixtures', 'web-component', 'android-sharedpreferences', 'avaudiorecorder', 'windbg', 'micronaut', 'gaming', 'angularjs-ng-click', 'fill', 'spinner', 'laravel-artisan', 'qlabel', 'csrf', 'mobilefirst-server', 'bittorrent', 'etcd', 'words', 'android-jetpack-navigation', 'doctype', 'bitmapdata', 'case', 'pause', 'arm64', 'gis', 'calloc', 'rollback', 'contact-form-7', 'filechooser', 'systemctl', 'javascriptserializer', 'android-navigation', 'autorotate', 'asp.net', 'x++', 'sql-delete', 'volume', 'redis', 'grepl', 'x86-16', 'apple', 'cgrect']}}, 'required': ['category']}}]
# response ChatCompletion(id='chatcmpl-AX8heRK1QdpJM7BtoT8VJZWIKd0yb', choices=[Choice(finish_reason='function_call', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', function_call=FunctionCall(arguments='{ "category": "gaming" }', name='entity_linking'), tool_calls=None))], created=1732461642, model='gpt-3.5-turbo-0125', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=19, prompt_tokens=1132, total_tokens=1151, completion_tokens_details=CompletionTokensDetails(audio_tokens=0, reasoning_tokens=0, accepted_prediction_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# filter_generator_output: {'category': 'gaming'}
# insert at 109
# 0

# %%
# current_model = AIModelType.GOOGLE_GEMINI_PRO

# import pandas as pd
import json
df = pd.read_json(f"./prediction_mantis_more_categories_{current_model}_v1.json")

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def classification_metrics(true_labels, predicted_labels):
    """
    Calculate and print classification metrics.

    Parameters:
    - true_labels: List of true labels
    - predicted_labels: List of predicted labels

    Returns:
    - metrics: Dictionary containing accuracy, precision, recall, and F1-score
    """
    metrics = {
        'accuracy': accuracy_score(true_labels, predicted_labels),
        'precision': precision_score(true_labels, predicted_labels, average='weighted'),
        'recall': recall_score(true_labels, predicted_labels, average='weighted'),
        'f1_score': f1_score(true_labels, predicted_labels, average='weighted')
    }

    print(f"Accuracy: {metrics['accuracy']:.2f}")
    print(f"Precision: {metrics['precision']:.2f}")
    print(f"Recall: {metrics['recall']:.2f}")
    print(f"F1 Score: {metrics['f1_score']:.2f}")

    return metrics

# Example usage
true_labels = df["category"].tolist()
predicted_labels = df["Prediction"].tolist()

print("predicted_labels:", predicted_labels)


classification_metrics(true_labels, predicted_labels)
# Out:
# predicted_labels: ['stats', 'dba', 'askubuntu', 'gaming', 'askubuntu', 'askubuntu', 'travel', 'apple', 'apple', 'askubuntu', 'electronics', 'askubuntu', 'english', 'security', 'physics', 'physics', 'security', 'askubuntu', 'dba', 'electronics', 'askubuntu', 'dba', 'askubuntu', 'gis', 'gis', 'askubuntu', 'askubuntu', 'stats', 'physics', 'apple', 'physics', 'electronics', 'security', 'askubuntu', 'gis', 'askubuntu', 'electronics', 'physics', 'gaming', 'stats', 'physics', 'scifi', 'electronics', 'scifi', 'askubuntu', 'worldbuilding', 'stats', 'askubuntu', 'physics', 'electronics', 'physics', 'dba', 'askubuntu', 'apple', 'askubuntu', 'stats', 'gaming', 'gaming', 'askubuntu', 'apple', 'travel', 'physics', 'english', 'gaming', 'askubuntu', 'askubuntu', 'electronics', 'apple', 'gis', 'security', 'gis', 'security', 'apple', 'askubuntu', 'english', 'apple', 'apple', 'gis', 'electronics', 'diy', 'electronics', 'security', 'scifi', 'stats', 'physics', 'travel', 'dba', 'askubuntu', 'askubuntu', 'askubuntu', 'electronics', 'english', 'english', 'physics', 'dba', 'gaming', 'electronics', 'askubuntu', 'stats', 'apple', 'diy', 'physics', 'askubuntu', 'gis', 'electronics', 'stats', 'electronics', 'gis', 'gis', 'gaming']
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'f1_score': 1.0}

# %% [markdown]
# We have lots of false negatives, as the model does not have all filter ids in schema for Function Call Model. We use custom filter ids for the experiment, to give them a fair chance.
